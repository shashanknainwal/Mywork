# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
from matplotlib import dates
import datetime as dt
import matplotlib.dates as mdates

# %%
features=pd.read_csv("/Users/shashank/Desktop/SpringboardDatascience/SB-Capstone-1/features.csv")

# %%
stores=pd.read_csv("/Users/shashank/Desktop/SpringboardDatascience/SB-Capstone-1/stores.csv")

# %%
train=pd.read_csv("/Users/shashank/Desktop/SpringboardDatascience/SB-Capstone-1/train.csv",parse_dates=True)

# %%
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106     False
# 1        NaN        NaN        NaN  211.242170         8.106      True
# 2        NaN        NaN        NaN  211.289143         8.106     False
# 3        NaN        NaN        NaN  211.319643         8.106     False
# 4        NaN        NaN        NaN  211.350143         8.106     False

# %%
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales IsHoliday
# 0      1     1  2010-02-05      24924.50     False
# 1      1     1  2010-02-12      46039.49      True
# 2      1     1  2010-02-19      41595.55     False
# 3      1     1  2010-02-26      19403.54     False
# 4      1     1  2010-03-05      21827.90     False

# %%
train.rename(columns={'Date':'MyDate'}).head()
# Out:
#    Store  Dept      MyDate  Weekly_Sales IsHoliday
# 0      1     1  2010-02-05      24924.50     False
# 1      1     1  2010-02-12      46039.49      True
# 2      1     1  2010-02-19      41595.55     False
# 3      1     1  2010-02-26      19403.54     False
# 4      1     1  2010-03-05      21827.90     False

# %%
#plotting some graphs

# %%
plt.plot(train["Dept"],train["Weekly_Sales"])
plt.xlabel('Dept')
plt.ylabel('Sales')
plt.tight_layout()
plt.show()

# %%
#plot bar graph

plt.hist2d(train["Dept"],train["Weekly_Sales"],bins=(10,20),range=((0,120),(10000,20000)))
plt.colorbar()
plt.xlabel('Dept')
plt.ylabel('Sales')
plt.axis('tight')
plt.show()

# %%
#plot hexbin

# %%
plt.hexbin(train["Dept"],train["Weekly_Sales"],gridsize=(10,20),extent=((1,10,10000,20000)))
plt.colorbar()
plt.xlabel('Dept')
plt.ylabel('Sales')
plt.axis('tight')
plt.show()

# %%
#x=mdates.date2num(train['MyDate'])
plt.plot(features['Date'],features['Temperature'],)
plt.xlabel('MyDate')
plt.ylabel('Sales')
plt.tight_layout()
plt.show()

# %%
 #convert date object to Pandas date format?


features['Date'] = features['Date'].astype('datetime64[ns]')

# %%
# trying seaborn

# %%
import seaborn as sns

# %%
sns.lmplot(x='CPI',y='Fuel_Price',data=features,hue='IsHoliday',palette='husl',col='IsHoliday')

# %%
sns.residplot(x='CPI',y='Fuel_Price',data=features,color='blue',order=1)

# %%
sns.lmplot(x='Store',y='Size',data=stores,hue='Type',palette='husl',col='Type')

# %%
#seaborn Strip Swarm and KDL plot

# %%
sns.stripplot(y='Size',x='Type',data=stores)

# %%
sns.swarmplot(y='Size',x='Store',data=stores,hue='Type')

# %%
sns.violinplot(y='Temperature',x='IsHoliday',data=features)

# %%
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
#multivariate plots- 2 variables or more variables relationship

# %%
#joint plot

# %%
features.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 1      1 2010-02-12        38.51       2.548        NaN        NaN        NaN
# 2      1 2010-02-19        39.93       2.514        NaN        NaN        NaN
# 3      1 2010-02-26        46.63       2.561        NaN        NaN        NaN
# 4      1 2010-03-05        46.50       2.625        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment IsHoliday
# 0        NaN        NaN  211.096358         8.106     False
# 1        NaN        NaN  211.242170         8.106      True
# 2        NaN        NaN  211.289143         8.106     False
# 3        NaN        NaN  211.319643         8.106     False
# 4        NaN        NaN  211.350143         8.106     False

# %%
sns.jointplot(x='Weekly_Sales',y='Dept',data=train)
plt.show()

# %%
sns.jointplot( x='CPI', y='Unemployment',data=features)
#optional- kind='scatter','reg','resid','kde','hex'

# %%
features.CPI.fillna(0, inplace=True)
features.Unemployment.fillna(0,inplace=True)
features.CPI = features.CPI.astype(int)
features.Unemployment = features.Unemployment.astype(int)

# %%
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# 5         1  2010-03-12        57.79       2.667        NaN        NaN
# 6         1  2010-03-19        54.58       2.720        NaN        NaN
# 7         1  2010-03-26        51.45       2.732        NaN        NaN
# 8         1  2010-04-02        62.27       2.719        NaN        NaN
# 9         1  2010-04-09        65.86       2.770        NaN        NaN
# 10        1  2010-04-16        66.32       2.808        NaN        NaN
# 11        1  2010-04-23        64.84       2.795        NaN        NaN
# ...

# %%
#pairplots- not able to draw
sns.pairplot(features)
plt.show()
#optional- use hue='' to group by that column and kind = one of the plot values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-3d6a95e2213d> in <module>()
#       1 #pairplots- not able to draw
# ----> 2 sns.pairplot(features)
#       3 plt.show()
#       4 clear
#
# //anaconda/lib/python3.5/site-packages/seaborn/linearmodels.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1607     if grid.square_grid:
#    1608         if diag_kind == "hist":
# -> 1609             grid.map_diag(plt.hist, **diag_kws)
#    1610         elif diag_kind == "kde":
#    1611             diag_kws["legend"] = False
#
# //anaconda/lib/python3.5/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1346                 else:
#    1347                     func(vals, color=self.palette, histtype="barstacked",
# ...

# %%
#heat map

# %%
sns.heatmap(covariance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-f94f2154b58a> in <module>()
# ----> 1 sns.heatmap(covariance)
#
# NameError: name 'covariance' is not defined

# %%
# virualizing time series

# %%
type(features.Date)
# Out:
# pandas.core.series.Series

# %%
type(train.Date)
# Out:
# pandas.core.series.Series

# %%
temp = features['Date']
march_apr=temp.loc[1:10]

# %%
march_apr
# Out:
# 1    2010-02-12
# 2    2010-02-19
# 3    2010-02-26
# 4    2010-03-05
# 5    2010-03-12
# 6    2010-03-19
# 7    2010-03-26
# 8    2010-04-02
# 9    2010-04-09
# 10   2010-04-16
# Name: Date, dtype: datetime64[ns]

# %%
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106     False
# 1        NaN        NaN        NaN  211.242170         8.106      True
# 2        NaN        NaN        NaN  211.289143         8.106     False
# 3        NaN        NaN        NaN  211.319643         8.106     False
# 4        NaN        NaN        NaN  211.350143         8.106     False

# %%
features1=features[(features.Date>'2010-02-01') &(features.Date<'2010-04-01')]
features1.set_index('Date')

# %%
#plot temperate for month of febraury and march
plt.plot(features1['Date'],features1['Temperature'],color='red',label='temperature')

# %%
clear

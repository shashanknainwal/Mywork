# %% [markdown]
#     # Seaborn Library for Data Visualization- beautiful design

# %% [markdown]
# # 1. Distribution Plots
# Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:
# distplot
# jointplot
# pairplot
# rugplot
# kdeplot

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde=False)
#give one column  

#KDE removed

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)

# %%
#Joint plot- matchup 2 distplots- combine 2 different distribution plot...

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')
#pass x and y as strings

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
#plots pair wise relationship between all numerical columns in the plot

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')
#hue takes categorical column

# %%
#rugplots

# %%
sns.rugplot(tips['total_bill'])

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0, 1)

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-d9500cc2c0f4> in <module>()
#       8
#       9 # Add the initial rugplot
# ---> 10 sns.rugplot(dataset,c = 'indianred')
#      11
#      12 # Get rid of y-tick marks
#
# //anaconda/lib/python3.5/site-packages/seaborn/distributions.py in rugplot(a, height, axis, ax, **kwargs)
#     636     kwargs.setdefault("linewidth", 1)
#     637     for pt in a:
# --> 638         func(pt, 0, height, **kwargs)
#     639
#     640     return ax
#
# //anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     786         self._process_unit_info(xdata=x, kwargs=kwargs)
#     787         xx = self.convert_xunits(x)
# --> 788         scalex = (xx < xmin) or (xx > xmax)
#     789
#     790         trans = self.get_xaxis_transform(which='grid')
#
# ...

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# #    2. Categorical Data Plots
#     Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:
#     factorplot
#     boxplot
#     violinplot
#     stripplot
#     swarmplot
#     barplot
#     countplot

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
# x categorical value
#y numerical value

# %%
sns.factorplot(x='sex',y='total_bill',data=tips)

# %%
sns.countplot(x='sex',data=tips)
#estimator =nuxmber of occurance on y axis

# %%
# shows quantititave  Box plot and violing

#shows disribution of quantitive data in a way to compare variable

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',split=True)
#scatter plot where one variable is categorical

# %%
#strip_violin= swarm dont use this plot for large dataset. dont really use it

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

#plotting multiple categorical plots together

# %%
#factor plpt- most general

# %%
#factorplot is the most general form of a categorical plot. It can take in a kind parameter to adjust the plot type:

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind='bar')

# %% [markdown]
# # 3. Matrix Plots
# Matrix plots allow you to plot data as color-encoded matrices and can also be used to indicate clusters within the data (later in the machine learning section we will learn how to formally cluster data).
# Let's begin by exploring seaborn's heatmap and clutermap:

# %%
flights = sns.load_dataset('flights')

# %%
tips = sns.load_dataset('tips')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#heat map shows matrix plot - data should be in matrix form.

# %%
tc=tips.corr()
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc,annot=True,cmap='coolwarm')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
fp=flights.pivot_table(index='month',columns='year',values='passengers')
fp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fp,cmap='magma',linecolor='white',linewidths=1)

# %%
# cluster Map- heirical clustering

# %%
sns.clustermap(fp)
# Out:
# //anaconda/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# More options to get the information a little clearer like normalization
sns.clustermap(fp,cmap='coolwarm',standard_scale=1)
# Out:
# //anaconda/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # 4. Regression Plots
# Seaborn has many built-in capabilities for regression plots, however we won't really discuss regression until the machine learning section of the course, so we will only cover the lmplot() function for now.
# lmplot allows you to display linear models, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.
# Let's explore how this works:

# %%
#lmplot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':100})
# male and female have same liner fit for total bill vs tip

# %% [markdown]
# Using a Grid
# We can add more variable separation through columns and rows with the use of a grid. Just indicate this with the col or row arguments:

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',aspect=0.6,size=8)

# %% [markdown]
# # Grids
# Grids are general types of plots that allow you to map plot types to rows and columns of a grid, this helps you create similar plots separated by features.

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#pair plot

# %%
g=sns.PairGrid(iris)
#essentially making subplots, kind of pairplot
#g.map(plt.scatter)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.pairplot(iris,hue='species',palette='rainbow')

# %% [markdown]
# Facets Grid
# FacetGrid is the general way to create grids of plots based off of a feature:

# %%
g=sns.FacetGrid(tips,col='time',row='smoker')

# %%
g=sns.FacetGrid(tips,col='time',row='smoker')
g.map(sns.distplot,'total_bill')
g.map(plt.scatter,'total_bill','tip')
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# # Style and Color
# We've shown a few times how to control figure aesthetics in seaborn, but let's now go over it formally:

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)
sns.despine(left=True,bottom=True)

# %% [markdown]
# #size and aspect
# You can use matplotlib's plt.figure(figsize=(width,height) to change the size of most seaborn plots.
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect. For example:

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %% [markdown]
# Scale and Context
# The set_context() allows you to override default parameters:

# %%
sns.set_context(context='poster',font_scale=3)
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %%
sns.countplot(x='sex',data=tips,palette='coolwarm')
#palatter- color map
